# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('car_crash.png')
plt.imshow(img)
print("Car Accident")
# Out:
# Car Accident

# %%
img = mpimg.imread('pothole.png')
plt.imshow(img)
print("Pothole detected")
# Out:
# Pothole detected

# %%
img = mpimg.imread('all_good.png')
plt.imshow(img)
print("All Good")
# Out:
# All Good
